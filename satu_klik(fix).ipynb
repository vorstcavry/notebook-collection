# %% [markdown]
# <a href="https://colab.research.google.com/github/vorstcavry/notebook-collection/blob/https%2Fgithub.com%2Fvorstcavry/satu_klik(fix).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# `Terakhir diperbarui : 14 Agustus 2023 | 15.05 WIB INDONESIA`
#
# <img src="https://camo.githubusercontent.com/82291b0fe831bfc6781e07fc5090cbd0a8b912bb8b8d4fec0696c881834f81ac/68747470733a2f2f70726f626f742e6d656469612f394575424971676170492e676966" width="800" height="3">
#
#
# <font color="#CC3E3E"><font size="6"><u><b>PERHATIAN</b></u>
#
# Dikarenakan peraturan google collab yang terbaru <b><a href="https://research.google.com/colaboratory/faq.html#limitations-and-restrictions"> Google Colab ToS</a></b> dan <b><a href="https://twitter.com/thechrisperry/status/1649189902079381505"> Official Statement</a></b>, diharapkan jangan menjalankan script jika terdapat warning sebagai berikut
#
# ![image.png](data:image/png;base64,...)
#
# saya tidak bertanggung jawab apabila anda tetap menjalankan dan akun anda ditangguhkan sehingga tidak bisa menggunakan google colab dalam jangka waktu yang ditentukan google.
#
#
# <img src="https://camo.githubusercontent.com/82291b0fe831bfc6781e07fc5090cbd0a8b912bb8b8d4fec0696c881834f81ac/68747470733a2f2f70726f626f742e6d656469612f394575424971676170492e676966" width="800" height="3">

# %% [markdown]
# # **Jangan lupa dibaca sampai bawah**
# untuk menjalankan script ini tidak diperlukan spek tinggi karena menggunakan layanan berbasis cloud milik google. untuk kecepatan download file tergantung koneksi internet google dan juga banyaknya file yang didownload

# %% [markdown]
# > <font color="#00CED1">**INFORMASI**:</font>
#
# 1. Karena adanya [Kebijakan] dan [Pernyataan Resmi][pernyataanresmi] Google Colab yang baru, sebagai pengguna google colab gratis akan dibatasi untuk penggunaan GPU dan CUDA***(komputasinya dibatasi)***
# 2. Jika akun sudah limit pemakaian google colab akun tersebut akan bisa dipakai lagi dalam waktu 24 jam kedepan.
# (1 akun google memiliki batas 12 jam pemakiaan)
# 3. Dengan mengganti akun google yang dipakai akan mereset limit pemakaian, tetapi ada batasan jumlah pergantian penggunaan secara wajar (maksimal 3 akun, usahakan jangan lebih)
# 4. Google Colab Alternatife V2.1 mengambil Referensi Google Colab milik [Adiim EF] dan Milik [NoCrypt]
# 5. Google Colab Alternatife V2.2 mengambil Referensi Google Colab milik [Linaqruf][Linaqruf]
#
#
#
# [kebijakan]: https://research.google.com/colaboratory/faq.html#limitations-and-restrictions
# [adiim ef]: https://www.facebook.com/Adiim.EF
# [NoCrypt]:https://github.com/NoCrypt
# [pernyataanresmi]: https://twitter.com/thechrisperry/status/1649189902079381505
# [Linaqruf]:https://github.com/Linaqruf
# ---
#
# > <font color="#CC3E3E">**PERINGATAN**:</font>
#
# Jangan pernah sering mengganti akun untuk mengatasi limit pengguaan google colab, karena itu sudah termasuk dalam pelanggaran dalam [kebijakan baru][baru] (usahakan tidak menggunakan lebih dari 3 akun)
#
# [baru]:https://research.google.com/colaboratory/intl/id/faq.html
# ---
#
#
#
# > <font color="#00CER1">**NOTEBOOK COLLECTION**:</font>
#
# | Koleksi Catatan | Deskripsi | Link |
# | --- | --- | --- |
# | [Fast_stable_diffusion_AUTOMATIC1111](https://colab.research.google.com/github/TheLastBen/fast-stable-diffusion/blob/main/fast_stable_diffusion_AUTOMATIC1111.ipynb)<font color="#CC3E3E">*Belum Stabil*</font> | Stable Diffuson V1.5 (TheLastBen) | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/TheLastBen/fast-stable-diffusion/blob/main/fast_stable_diffusion_AUTOMATIC1111.ipynb) |  [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-dreambooth.ipynb) |
# | [Satu Klik Stable Diffusion](https://colab.research.google.com/drive/1LFohDgoe1U3rYwbAUFSLp1K6yM1QNG6i?usp=sharing) <font color="#7FFF00">*Fix Update*</font>| Stable Diffuson V1.5 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1LFohDgoe1U3rYwbAUFSLp1K6yM1QNG6i?usp=sharing) |
# | [Membuat LoRA](https://colab.research.google.com/drive/1wo3hz402iQTb1ilz6zv6g1sotMlM-qoS?usp=sharing) <font color="#CC3E3E">**(TAHAP PERBAIKAN)**</font> | Google Colab Membuat LoRA  | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1wo3hz402iQTb1ilz6zv6g1sotMlM-qoS?usp=sharing) |
# | [Kohya LoRA Dreambooth](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-dreambooth.ipynb)  <font color="#7FFF00">*Normal*</font>| Membuat LoRA (Linaqruf) | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-dreambooth.ipynb) |
# | [Kohya LoRA Finetuner](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-finetuner.ipynb) <font color="#7FFF00">*Normal*</font>| Membuat LoRA 2 (Linaqruf) | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-finetuner.ipynb) |
# | [Fast SD Chilloutmix](https://colab.research.google.com/drive/1Ty7uB6kZa_cfraZG-G6Rzu3B_spunJFy?usp=sharing) <font color="#7FFF00">*Normal*</font>| Stable Diffuson V1 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1Ty7uB6kZa_cfraZG-G6Rzu3B_spunJFy?usp=sharing) |
# | [Fast SD Shadow Garden](https://colab.research.google.com/drive/1zfLPHL7MKvFtIBxUezF0O_SVb6yS6W6I?usp=sharing)  <font color="#7FFF00">*Normal*</font>|Stable Diffusion V1|[![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1zfLPHL7MKvFtIBxUezF0O_SVb6yS6W6I?usp=sharing)|
# | [A1 Alternatif V2.1](https://colab.research.google.com/drive/1zxSTb-olxIfJeBslZL6H967_vEnzlGZi?usp=sharing)  <font color="#7FFF00">*Fix Update*</font>| Stable Diffuson V2.1 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1zxSTb-olxIfJeBslZL6H967_vEnzlGZi?usp=sharing) |
# | [A2 Alternatif Spesial ](https://colab.research.google.com/drive/1pTC4P17ZkFKAxNX2UVnwU0c6bn8DRWwv?usp=sharing)   <font color="#7FFF00">*Fix Update*</font>| Stable Diffuson V2.2 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1pTC4P17ZkFKAxNX2UVnwU0c6bn8DRWwv?usp=sharing)|
# | [Alternatif Spesial `KHUSUS SAWERIA`](https://colab.research.google.com/drive/1cRZwgt0WvJCDML4OI860fYKF2HaDW6SY?usp=sharing)   <font color="#7FFF00">*Fix Update*</font>| Stable Diffuson V2.2 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1cRZwgt0WvJCDML4OI860fYKF2HaDW6SY?usp=sharing) |
# | [Alternatif Spesial Satu Klik](https://colab.research.google.com/drive/1LjOYLyFgaeB2CAXVgmfkuK5mQ3XoAIRI#scrollTo=VNi70r9E4nPM)  <font color="#7FFF00">*Fix Update*</font>| Stable Diffuson V2.2 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1LjOYLyFgaeB2CAXVgmfkuK5mQ3XoAIRI#scrollTo=VNi70r9E4nPM) |
# |[Cagliostro-Colab-UI](https://colab.research.google.com/github/Linaqruf/sd-notebook-collection/blob/main/cagliostro-colab-ui.ipynb#scrollTo=SaAJk33ppFw1) <font color="#FFD700">*Has stopped updating*</font>|Linaqruf Stable Diffusion|[![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/sd-notebook-collection/blob/main/cagliostro-colab-ui.ipynb#scrollTo=SaAJk33ppFw1)|
# | [Huggingface Collection Galery](https://huggingface.co/spaces/huggingface-projects/diffusers-gallery) | Koleksi Galeri Huggingface | [![Hugging Face Spaces](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/huggingface-projects/diffusers-gallery)|
# | [VAE Collection](https://huggingface.co/vorstcavry/vaecollection1/tree/main)| Koleksi VAE | [![Hugging Face Spaces](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/vorstcavry/vaecollection/tree/main)|
# | [AI Voice Changer](https://huggingface.co/spaces/vorstcavry/vits-models) | AI Pengubah Suara | [![Hugging Face Spaces](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/vorstcavry/vits-models)|
# | [AI Remove Background](https://huggingface.co/spaces/vorstcavry/anime-remove-background) | AI Penghapus Background | [![Hugging Face Spaces](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/vorstcavry/anime-remove-background)|
# | [Stable Diffusion Extension](https://github.com/AUTOMATIC1111/stable-diffusion-webui/wiki/Extensions) | Extension Stable Diffusion |[![Extension](https://badgen.net/badge/icon/GitHub?icon=github&label=Stable%20Diffusion)](https://github.com/AUTOMATIC1111/stable-diffusion-webui/wiki/Extensions)|
#
# ---

# %% [markdown]
# <CENTER><font color="#CC3E3E"><font size="6"><u><b>PERINGATAN</b></u><CENTER>
# DILARANG KERAS MENYEBARKAN GAMBAR DENGAN KONTEN NSFW REALISIC KE MEDIA SOSIAL

# %%
#@title <font size="5"><font color="#FFFF5F">**Preview Tema :**</font>
#@markdown  untuk melihat preview semua tema yang bisa dipakai klik tombol [ < ] atau [ > ]

#https://www.w3schools.com/w3css/w3css_slideshow.asp
import IPython
IPython.display.HTML(

'''

<html>
<title>W3.CSS</title>
<meta name="viewport" content="width=device-width, initial-scale=1">
<link rel="stylesheet" href="https://www.w3schools.com/w3css/4/w3.css">
<style>
.mySlides {display:none;}
</style>
<body>

<div class="w3-content w3-display-container">

<div class="w3-display-container mySlides">
  <img src="https://i.postimg.cc/tC0zC8sK/Screenshot-172-picsay.png" style="width:100%">
</div>

<div class="w3-display-container mySlides">
  <img src="https://i.postimg.cc/Xq5ckkz1/CATPPUCIN.png" style="width:100%">
</div>

<div class="w3-display-container mySlides">
  <img src="https://i.postimg.cc/v8xzyGZ7/DEVDARK.png" style="width:100%">
</div>

<div class="w3-display-container mySlides">
  <img src="https://i.postimg.cc/VLFs7Cw3/DOKI-Jupiter.png" style="width:100%">
</div>

<div class="w3-display-container mySlides">
  <img src="https://i.postimg.cc/FF3HL6BF/LINAQRUF.png" style="width:100%">
</div>

<div class="w3-display-container mySlides">
  <img src="https://i.postimg.cc/m242NSvY/Nocypt-Miku.png" style="width:100%">
</div>

<div class="w3-display-container mySlides">
  <img src="https://i.postimg.cc/jStQyNQv/KITCHEN.png" style="width:100%">
</div>

<div class="w3-display-container mySlides">
  <img src="https://i.postimg.cc/rwjGjmfT/LOBEHUB.png" style="width:100%">
</div>

<div class="w3-display-container mySlides">
  <img src="https://i.postimg.cc/ZKrx9j3C/ANAPNOE.png" style="width:100%">
</div>

<button class="w3-button w3-display-left w3-black" onclick="plusDivs(-1)">&#10094;</button>
<button class="w3-button w3-display-right w3-black" onclick="plusDivs(1)">&#10095;</button>

</div>

<script>
var slideIndex = 1;
showDivs(slideIndex);

function plusDivs(n) {
  showDivs(slideIndex += n);
}

function showDivs(n) {
  var i;
  var x = document.getElementsByClassName("mySlides");
  if (n > x.length) {slideIndex = 1}
  if (n < 1) {slideIndex = x.length}
  for (i = 0; i < x.length; i++) {
     x[i].style.display = "none";
  }
  x[slideIndex-1].style.display = "block";
}
</script>

</body>
</html>

''')
# Out:
# <html>
# <title>W3.CSS</title>
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <link rel="stylesheet" href="https://www.w3schools.com/w3css/4/w3.css">
# <style>
# .mySlides {display:none;}
# </style>
# <body>
#
# <div class="w3-content w3-display-container">
#
# <div class="w3-display-container mySlides">
#   <img src="https://i.postimg.cc/tC0zC8sK/Screenshot-172-picsay.png" style="width:100%">
# </div>
#
# <div class="w3-display-container mySlides">
#   <img src="https://i.postimg.cc/Xq5ckkz1/CATPPUCIN.png" style="width:100%">
# </div>
#
# <div class="w3-display-container mySlides">
#   <img src="https://i.postimg.cc/v8xzyGZ7/DEVDARK.png" style="width:100%">
# </div>
#
# <div class="w3-display-container mySlides">
#   <img src="https://i.postimg.cc/VLFs7Cw3/DOKI-Jupiter.png" style="width:100%">
# </div>
#
# <div class="w3-display-container mySlides">
#   <img src="https://i.postimg.cc/FF3HL6BF/LINAQRUF.png" style="width:100%">
# </div>
#
# ...

# %% [markdown]
# <center>
#
# #<font color="#FFD700">***STABLE DIFFUSION SATU KLIK***</font>
#
# <img src="https://user-images.githubusercontent.com/73097560/115834477-dbab4500-a447-11eb-908a-139a6edaec5c.gif" width="800" height="18">
#
#
#
# *Bagi yang mau support saya bisa menuju Saweria, KO-FI dan Trakteer dibawah ini*
#
# *For those who want to support me, you can go to Saweria, KO-FI and Trakteer below*
#
#  <a href="https://saweria.co/VorstCavry"><img alt="Saweria" src="https://img.shields.io/badge/Saweria-7B3F00?style=for-the-badge&logo=ko-fi&logoColor=white"/></a> <a href="https://ko-fi.com/vorstcavry"><img alt="KO-FI" src="https://img.shields.io/badge/Ko--fi-F16061?style=for-the-badge&logo=ko-fi&logoColor=white "/></a> <a href="https://trakteer.id/vorstcavry/tip"><img alt="YOUTUBE" src="https://img.shields.io/badge/trakteer-F16061?style=for-the-badge&logo=buy-me-a-coffee&logoColor=white"/></a><a href="https://wa.me/6285726996330"><img alt="Whatsapp" src="https://img.shields.io/badge/WhatsApp-25D366?style=for-the-badge&logo=whatsapp&logoColor=white"/></a> <a href="https://www.youtube.com/@remajapekalongan"><img alt="YOUTUBE" src="https://img.shields.io/badge/YouTube-%23FF0000?style=for-the-badge&logo=YouTube&logoColor=white"/></a>
# <a href="https://www.paypal.com/paypalme/vorstcavry?country.x=ID&locale.x=id_ID"><img alt="PAYPAL" src="https://img.shields.io/badge/PayPal-00457C?style=for-the-badge&logo=paypal&logoColor=white"/></a>
# <a href="https://www.instagram.com/vorst_cavry/"><img alt="INSTAGRAM" src="https://img.shields.io/badge/Instagram-E4405F?style=for-the-badge&logo=instagram&logoColor=white"/></a><a href="https://visitorbadge.io/status?path=https%3A%2F%2Fgithub.com%2Fvorstcavry"><img src="https://api.visitorbadge.io/api/visitors?path=https%3A%2F%2Fgithub.com%2Fvorstcavry&label=VISITORS&countColor=%23263759&labelStyle=none" /></a>

# %% [markdown]
# ##<font color="#7FFF00">***Big Update satu klik(fix)***</font>

# %%
from IPython.display import HTML, display

def display_text_box(content, width="485px", height="30px"):
    html_content = f'''
        <div style="
            display: flex;
            align-items: center;
            justify-content: center;
            border: 2px solid #ccc;
            background-color: #007bff;
            width: {width};
            height: {height};
            color: white;
            font-weight: bold;
            text-align: center;
        ">{content}</div>
    '''
    display(HTML(html_content))

text_content = "Terima kasih Telah Menggunakan Notebook google colab StableDiffusion milik Remaja Pekalongan."

display_text_box(text_content, width="485px", height="30px")

from IPython.display import HTML, Image

def display_image():
    image_url = "https://i.postimg.cc/Pf3XXMsP/Cuplikan-layar-2023-07-30-165548.png"
    image_html = f'<a href="https://www.youtube.com/@remajapekalongan" target="_blank"><img src="{image_url}" width="489" height="172"></a>'

    display(HTML(image_html))

display_image()
from IPython.display import HTML

def create_button_with_link(label, link):
    button_id = label.lower().replace(" ", "_")
    return f'''
        <style>
            #{button_id} {{
                width: 119px;
                height: 40px;
                background-color: #007bff;
                color: white;
                border: 2px solid #ccc;
                cursor: pointer;
                transition: background-color 0.3s;
            }}
            #{button_id}:hover {{
                background-color: #0056b3;
            }}
        </style>
        <a href="{link}" target="_blank" style="text-decoration: none;">
            <button id="{button_id}">{label}</button>
        </a>
    '''

subscribe_button = create_button_with_link("Subscribe", "https://www.youtube.com/@remajapekalongan")
support_button = create_button_with_link("Support", "https://ko-fi.com/vorstcavry")
saweria_button = create_button_with_link("Saweria", "https://http://saweria.co/vorstcavry")
discord_button = create_button_with_link("Discord", "https://discord.gg/fg9kvMqUmD")

buttons_html = f'<div>{subscribe_button} {support_button} {saweria_button} {discord_button}</div>'
display(HTML(buttons_html))


import os
import time
import json
import base64
import shutil
import subprocess
import threading
import sys
import random
import string
from IPython.display import display, HTML
from google.colab.output import eval_js
from IPython.utils import capture
from tqdm import tqdm
from pydantic import BaseModel

packages = [
            "pip install gradio_client==0.2.7",
            "pip install git+https://github.com/Linaqruf/colablib",
            "pip install --upgrade urllib3 chardet charset_normalizer requests"
            ]

for install in tqdm(packages, desc=print("Tunggu Sebentar...")):
    os.system(install)

from colablib.utils.py_utils import get_filename
from typing import List, Optional
from colablib.colored_print import cprint, print_line
from colablib.utils import py_utils, config_utils, package_utils
from colablib.utils.config_utils import pastebin_reader as read
from colablib.utils.ubuntu_utils import ubuntu_deps
from colablib.sd_models.downloader import aria2_download, download, get_modelname
from colablib.utils.ubuntu_utils import unionfuse
from colablib.utils.config_utils import read_config
from colablib.utils.git_utils import update_repo, batch_update, validate_repo, reset_repo, patch_repo




#Variabel
pt      = ".pt"
st      = ".safetensors"
civitai = "https://civitai.com/api/download/models/"
masbro  = {

      0  : ( "stable"    )
    , 1  : ( "diffusion" )
    , 2  : ( "webui"     )
    , 3  : ( "sd"        )
    , 4  : ( "Stable"    )
    , 5  : ( "Diffusion" )
    , 6  : ( "WebUI"     )
    , 7  : ( "SD"        )

}
#Import modul
from   datetime        import datetime
from   IPython.display import clear_output


#######################


#Lokasi folder
sd                = f"{masbro[0]}-{masbro[1]}"
wui               = f"{masbro[2]}"
sdwui             = f"{sd}-{wui}"
basemodelpath     = f"/content/vorst-cavry/models/Stable-diffusion"
vaepath           = f"/content/vorst-cavry/models/VAE"
embeddingpath     = f"/content/vorst-cavry/embeddings"
loramodelpath     = f"/content/vorst-cavry/models/Lora"
rooppath          = f"/content/vorst-cavry/models/roop"
contrlnetpath     = f"/content/vorst-cavry/extensions/sd-{wui}-controlnet/models"
addnetworkpath    = f"/content/vorst-cavry/extensions/sd-{wui}-additional-networks/models/lora"
esrganpath        = f"/content/vorst-cavry/models/ESRGAN"

def isnumber(s):
    try:
        float(s)
        return True
    except ValueError:
        return False


#!apt-get -y install -qq aria2
#!apt-get -y install libcairo2-dev pkg-config python3-dev
#!pip install --upgrade fastapi==0.90.1
#!pip install triton
#!pip install -q torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 torchtext==0.14.1 torchdata==0.5.1 torchmetrics==0.11.4 --extra-index-url https://download.pytorch.org/whl/cu116 -U

#!apt -y install -qq aria2 libcairo2-dev pkg-config python3-dev
#!pip install -q torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 torchtext==0.14.1 torchdata==0.5.1 torchmetrics==0.11.4 --extra-index-url https://download.pytorch.org/whl/cu116 -U

#%env TF_CPP_MIN_LOG_LEVEL=1

#!apt -y update -qq
#!wget https://huggingface.co/vorstcavry/backup-file/resolve/main/libtcmalloc_minimal.so.4 -O /content/libtcmalloc_minimal.so.4
#%env LD_PRELOAD=/content/libtcmalloc_minimal.so.4

#!apt -y install -qq aria2 libcairo2-dev pkg-config python3-dev

#######################################
#jika bagian atas tidak berfungsi maka gunakan bagian ini
#########################################
root_dir            = "/content"
repo_dir            = os.path.join(root_dir, "vorst-cavry")
tmp_dir             = os.path.join(root_dir, "tmp")
patches_dir         = os.path.join(root_dir, "patches")
deps_dir            = os.path.join(root_dir, "deps")
fused_dir           = os.path.join(root_dir, "fused")

# REPO DIR
models_dir          = os.path.join(repo_dir, "models", "Stable-diffusion")
vaes_dir            = os.path.join(repo_dir, "models", "VAE")
hypernetworks_dir   = os.path.join(repo_dir, "models", "hypernetworks")
lora_dir            = os.path.join(repo_dir, "models", "Lora")
control_dir         = os.path.join(repo_dir, "models", "ControlNet")
embeddings_dir      = os.path.join(repo_dir, "embeddings")
extensions_dir      = os.path.join(repo_dir, "extensions")
annotator_dir       = os.path.join(extensions_dir, f"sd-{wui}-controlnet", "annotator")
output_subdir       = ["txt2img-images", "img2img-images", "extras-images", "txt2img-grids", "img2img-grids"]

# CONFIG
config_file         = os.path.join(repo_dir, "config.json")
ui_config_file      = os.path.join(repo_dir, "ui-config.json")
style_path          = os.path.join(repo_dir, "style.css")
download_list       = os.path.join(root_dir, "download_list.txt")


def pre_download(dir, urls, desc, overwrite=False):
    gpu_info              = py_utils.get_gpu_info()
    version               = py_utils.get_python_version().split()[0]
    major_minor           = ".".join(version.split(".")[:2])
    xformers_version      = "0.0.20"
    insightface_version   = "0.7.3"
    python_path           = f"/usr/local/lib/python{major_minor}/dist-packages/"
    ffmpy_path            = os.path.join(python_path, "ffmpy-0.3.1.dist-info")

def install_dependencies():
    ubuntu_deps = ["aria2"]
    python_deps = ["ffmpy"]
    cprint("Mempersiapkan bahan ", color="green")
    subprocess.run(["apt", "install"] + ubuntu_deps)
    subprocess.run(["pip", "install"] + python_deps)

install_dependencies()
#install-stablediffusion

#@markdown <font size="3"><font color="#00F090">**Pilih Tema:**</font>

#@markdown > Tema `Anapnoe`, `Lobehub` dan `Kitchen` cocok untuk pengguna Mobile.
tema = "automatic1111" #@param ["automatic1111","catppuccin", "doki-jupiter", "linaqruf", "nocrypt-miku", "devdark", "anapnoe", "lobehub", "kitchen"]
gunakan_tema_gelap = False # @param {type: 'boolean'}
#@markdown <font size="3"><font color="#00F090">**Simpan Hasil Gambar di Google Drive:**</font>

from colablib.utils.git_utils import clone_repo
from colablib.utils.git_utils import update_repo, batch_update, validate_repo, reset_repo, patch_repo
from colablib.colored_print import cprint as cp
from urllib.parse import urlparse

def git_clone(repo_url, destination_folder):
    command = ['git', 'clone', repo_url, destination_folder]
    subprocess.call(command)

def download_with_aria2(url, output_dir):
    if not os.path.exists('/usr/bin/aria2c'):
        print("Error: aria2 tidak terpasang. Silakan pasang terlebih dahulu.")
        return

    if not os.path.exists(output_dir):
        print("Error: Direktori output tidak ditemukan.")
        return

    command = f'aria2c -d {output_dir} {url}'
    os.system(command)

def delete_directory(path):
    try:
        os.system(f"rm -rf {path}")
    except Exception as e:
        print(f"nothing: {str(e)}")

if (tema == "automatic1111") :
  repo_url = 'https://tinyurl.com/Vorst-Cavry-Auto1111'
  destination_folder = '/content/vorst-cavry'
  git_clone(repo_url, destination_folder)
  cp("Menggunakan Tema Automatic1111", color='flat_green')
elif (tema == "catppuccin") :
  repo_url = 'https://tinyurl.com/Vorst-Cavry-Auto1111'
  destination_folder = '/content/vorst-cavry'
  git_clone(repo_url, destination_folder)
  repo_url = 'https://tinyurl.com/CATPPUCCIN-Repo'
  destination_folder = '/content/vorst-cavry/extensions/catppuccin-theme'
  git_clone(repo_url, destination_folder)
  cp("Menggunakan Tema Catppuccin", color='flat_green')
elif (tema == "doki-jupiter") :
  repo_url = 'https://tinyurl.com/Vorst-Cavry-Auto1111'
  destination_folder = '/content/vorst-cavry'
  git_clone(repo_url, destination_folder)
  repo_url = 'https://github.com/vorstcavry/doki-theme'
  destination_folder = '/content/vorst-cavry/extensions/doki-theme'
  git_clone(repo_url, destination_folder)
  cp("Menggunakan Tema Doki", color='flat_green')
elif (tema == "linaqruf") :
  repo_url = 'https://tinyurl.com/Vorst-Cavry-Auto1111'
  destination_folder = '/content/vorst-cavry'
  git_clone(repo_url, destination_folder)
  url = 'https://huggingface.co/vorstcavry/test/resolve/main/ui-config.json'
  output_directory = os.path.join(repo_dir)
  download_with_aria2(url, output_directory)
  url = 'https://huggingface.co/vorstcavry/test/resolve/main/config.json'
  output_directory = os.path.join(repo_dir)
  download_with_aria2(url, output_directory)
  cp("Menggunakan Tema Linaqruf", color='flat_green')
elif (tema == "nocrypt-miku") :
  repo_url = 'https://tinyurl.com/Vorst-Cavry-Auto1111'
  destination_folder = '/content/vorst-cavry'
  git_clone(repo_url, destination_folder)
  url = 'https://huggingface.co/vorstcavry/test/resolve/main/Nocrypt/ui-config.json'
  output_directory = os.path.join(repo_dir)
  download_with_aria2(url, output_directory)
  url = 'https://huggingface.co/vorstcavry/test/resolve/main/Nocrypt/config.json'
  output_directory = os.path.join(repo_dir)
  download_with_aria2(url, output_directory)
  url = 'https://huggingface.co/vorstcavry/test/resolve/main/Nocrypt/user.css'
  output_directory = os.path.join(repo_dir)
  download_with_aria2(url, output_directory)
  url = 'https://huggingface.co/vorstcavry/test/resolve/main/Nocrypt/nohup.out'
  output_directory = os.path.join(repo_dir)
  download_with_aria2(url, output_directory)
  url = 'https://huggingface.co/vorstcavry/test/resolve/main/Nocrypt/JetBrainsMono-Regular.woff2'
  output_directory = os.path.join(repo_dir)
  download_with_aria2(url, output_directory)
  url = 'https://huggingface.co/vorstcavry/test/resolve/main/Nocrypt/logo.png'
  output_directory = os.path.join(repo_dir)
  download_with_aria2(url, output_directory)
  delete_directory(f"{repo_dir}/style.css")
  url = 'https://huggingface.co/vorstcavry/test/resolve/main/Nocrypt/style.css'
  output_directory = os.path.join(repo_dir)
  download_with_aria2(url, output_directory)
  delete_directory(f"{repo_dir}/webui.py")
  url = 'https://huggingface.co/vorstcavry/test/resolve/main/Nocrypt/webui.py'
  output_directory = os.path.join(repo_dir)
  download_with_aria2(url, output_directory)
  delete_directory(f"{repo_dir}/extensions-builtin/extra-options-section/scripts/extra_options_section.py")
  delete_directory(f"{repo_dir}/modules/ui_settings.py")
  delete_directory(f"{repo_dir}/modules/scripts.py")
  url = 'https://huggingface.co/vorstcavry/test/resolve/main/nr/extra_options_section.py'
  output_directory = os.path.join(repo_dir, "extensions-builtin", "extra-options-section", "scripts")
  download_with_aria2(url, output_directory)
  url = 'https://huggingface.co/vorstcavry/test/resolve/main/nr/scripts.py'
  output_directory = os.path.join(repo_dir, "modules")
  download_with_aria2(url, output_directory)
  url = 'https://huggingface.co/vorstcavry/test/resolve/main/nr/ui_settings.py'
  output_directory = os.path.join(repo_dir, "modules")
  download_with_aria2(url, output_directory)
  cp("Menggunakan Tema Nocrypt Miku", color='flat_green')
  cp("Maaf Untuk Tema Nocrypt Miku penggunaan Lycoris Masih Belum Stabil", color='flat_red')
elif (tema == "devdark") :
  repo_url = 'https://tinyurl.com/Vorst-Cavry-Auto1111'
  destination_folder = '/content/vorst-cavry'
  git_clone(repo_url, destination_folder)
  repo_url = 'https://tinyurl.com/Devdark-Theme'
  destination_folder = '/content/vorst-cavry/extensions/devdark-theme'
  git_clone(repo_url, destination_folder)
  cp("Menggunakan Tema Devdark", color='flat_green')
elif (tema == "anapnoe") :
  repo_url = 'https://tinyurl.com/Anapnoe-ux-Repo'
  destination_folder = '/content/vorst-cavry'
  git_clone(repo_url, destination_folder)
  hires_prompt_fix = "https://gist.githubusercontent.com/Linaqruf/8fef456d53604f8c3bcd16722ea7d2f6/raw/a3382087c6e32f9a171f4b5e8aeb572a61682801/0001-Add-New-Label-for-Hires-Prompt.patch"
  patch_repo(url=hires_prompt_fix, dir=patches_dir, cwd=repo_dir, whitespace_fix=True, quiet=True)
  shutil.rmtree(patches_dir)
  cp("Menggunakan Tema Anepnoe", color='flat_green')
elif (tema == "lobehub") :
  repo_url = 'https://tinyurl.com/Vorst-Cavry-Auto1111'
  destination_folder = '/content/vorst-cavry'
  git_clone(repo_url, destination_folder)
  repo_url = 'https://tinyurl.com/LOBE-Repo'
  destination_folder = '/content/vorst-cavry/extensions/lobe-theme'
  git_clone(repo_url, destination_folder)
  cp("Menggunakan Tema Lobe", color='flat_green')
elif (tema == "kitchen") :
  repo_url = 'https://tinyurl.com/Vorst-Cavry-Auto1111'
  destination_folder = '/content/vorst-cavry'
  git_clone(repo_url, destination_folder)
  repo_url = 'https://tinyurl.com/KITCHEN-Repo'
  destination_folder = '/content/vorst-cavry/extensions/kitchen-theme'
  git_clone(repo_url, destination_folder)
  cp("Menggunakan Tema Kitchen", color='flat_green')
else :
  pass



drive = False #@param {type:"boolean"}

if drive:
   from google.colab import drive
   drive.mount('/content/vorst-cavry/outputs')
   cp("Menggunakan Penyimpanan hasil ke Google Drive", color='flat_green')
   drive = {
         "outdir_samples": "outputs/MyDrive/outputs",
         "outdir_txt2img_samples": "outputs/MyDrive/outputs",
         "outdir_img2img_samples": "outputs/MyDrive/outputs",
         "outdir_extras_samples": "outputs/MyDrive/outputs",
         "outdir_grids": "outputs/MyDrive/outputs",
         "outdir_txt2img_grids": "outputs/MyDrive/outputs",
         "outdir_img2img_grids": "outputs/MyDrive/outputs"
   }
else:
     cp("Menggunakan Penyimpanan hasil ke Google Colab", color='flat_green')
     drive = {
           "outdir_samples": "outputs",
           "outdir_txt2img_samples": "outputs",
           "outdir_img2img_samples": "outputs",
           "outdir_extras_samples": "outputs",
           "outdir_grids": "outputs",
           "outdir_txt2img_grids": "outputs",
           "outdir_img2img_grids": "outputs"
     }


def download_with_aria2(url, output_dir):
    if not os.path.exists('/usr/bin/aria2c'):
        print("Error: aria2 tidak terpasang. Silakan pasang terlebih dahulu.")
        return

    if not os.path.exists(output_dir):
        print("Error: Direktori output tidak ditemukan.")
        return

    command = f'aria2c -d {output_dir} {url}'
    os.system(command)


url = 'https://huggingface.co/vorstcavry/test/resolve/main/styles.csv'
output_directory = os.path.join(repo_dir)
download_with_aria2(url, output_directory)

#install-bahan-dasar
os.chdir(repo_dir)
def git_clone(repo_url, destination_folder):
    command = ['git', 'clone', repo_url, destination_folder]
    subprocess.call(command)

repo_url = 'https://github.com/vorstcavry/lora'
destination_folder = os.path.join(repo_dir, "models", "Lora", "Lora-set")
git_clone(repo_url, destination_folder)


def delete_directory(path):
    try:
        os.system(f"rm -rf {path}")
    except Exception as e:
        print(f"nothing: {str(e)}")

delete_directory(f"{repo_dir}/models/Lora/Lora-set/.git")
os.chdir(repo_dir)
embedding = [
             f"rm -rf {repo_dir}/embeddings",
             f"git clone https://github.com/vorstcavry/embeddings {repo_dir}/embeddings >/dev/null 2>&1",
             f"rm -rf {repo_dir}/embeddings/.git"
             ]

for embedd in tqdm(embedding,  desc=cp("Mempersipkan Embeddings", color="flat_green")):
    os.system(embedd)
#instal-Preview
#install-upscale
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/embed/upscale/resolve/main/4x-UltraSharp.pth -d /content/vorst-cavry/models/ESRGAN -o 4x-UltraSharp.pth
#install-ekstension
extensions_url = [
                   "KohakuBlueleaf/LyCORIS",
                   "Coyote-A/ultimate-upscale-for-automatic1111",
                   "Iyashinouta/sd-colab-commands-browser",
                   "Iyashinouta/sd-model-downloader",
                   "NoCrypt/inpaint-nav",
                   "vorstcavry/sd-civitai-browser",
                   "vorstcavry/vorstcavry-tunnels",
                   "vorstcavry/openpose-editor",
                   "vorstcavry/depth-lib",
                   "vorstcavry/roop",
                   "vorstcavry/ratio-helper",
                  f"Mikubill/sd-{wui}-controlnet",
                  f"deforum-art/deforum-for-automatic1111-{wui}",
                  f"etherealxx/batchlinks-{wui}",
                  f"Uminosachi/sd-{wui}-inpaint-anything",
                  f"Mikubill/sd-{wui}-controlnet",
                  f"DominikDoom/a1111-sd-{wui}-tagcomplete",
                  f"camenduru/sd-{wui}-additional-networks",
                  f"yfszzx/{sdwui}-images-browser",
                  ]


cp("Memperispkan Vorst-Cavry-Auto1111", color='flat_green')

root_dir = "/content"
repo_dir = os.path.join(root_dir, "vorst-cavry")
extensions_dir = os.path.join(repo_dir, "extensions")

os.chdir(extensions_dir)
for batch in tqdm(extensions_url, desc=cp(f"Mempersiapkan Ekstension", color="flat_green")):
    parse = urlparse(batch)
    path = os.path.basename(parse.path)
    if not os.path.exists(f"{extensions_dir}/{path}"):
       clone_repo(f"https://github.com/{batch}", quiet=True)
    else:
         pass
#install-controlnet
#@markdown <font size="3"><font color="#00F090">**Pilih Model/Download Model:**</font>
Pilih_Model = "cavry_v2" #@param ["AOAOKO_PVC_Anime", "DeliberateV2_AIO", "ChillOutMixNiFP16Fix_Realistic", "MeinaPastelV4_Anime", "majicmixRealistic_v6", "PerfectWorldV2_Realistic", "AnythingV5_Anime", "anyloraCheckpoint_bakedvaeBlessedFp16", "cuteyukimixAdorable_neochapter3", "cavry_v2"]
Custom_Download = "" #@param {type:"string"}
cpoint = None
cpointurl = None
if Pilih_Model == "AOAOKO_PVC_Anime":
   cpoint="https://civitai.com/api/download/models/18295"
if Pilih_Model == "DeliberateV2_AIO":
   cpoint="https://civitai.com/api/download/models/15236"
if Pilih_Model == "ChillOutMixNiFP16Fix_Realistic":
   cpoint="https://civitai.com/api/download/models/11732"
if Pilih_Model == "MeinaPastelV4_Anime":
   cpoint="https://civitai.com/api/download/models/27135"
if Pilih_Model == "majicmixRealistic_v6":
   cpoint="https://civitai.com/api/download/models/94640"
if Pilih_Model == "PerfectWorldV2_Realistic":
   cpoint="https://civitai.com/api/download/models/19084"
if Pilih_Model == "AnythingV5_Anime":
   cpoint="https://civitai.com/api/download/models/30163"
if Pilih_Model == "anyloraCheckpoint_bakedvaeBlessedFp16":
   cpoint="https://civitai.com/api/download/models/95489"
if Pilih_Model == "cuteyukimixAdorable_neochapter3":
   cpoint="https://civitai.com/api/download/models/138620"
if Pilih_Model == "cavry_v2":
   cpoint="https://civitai.com/api/download/models/134860"
if Custom_Download:
   cpointurl=Custom_Download
else:
     pass


from colablib.sd_models.downloader import aria2_download as download
import requests
import sys

def downloading(download_dir=None, url=None, quiet=True):
    try:
        if url.find("https://civitai.com/")!=-1:
           convert = "" + url.replace("download/models", "v1/model-versions")
           req = requests.get(convert, stream=True)
           path = req.json()['files'][0]['name']
           size = int(req.json()['files'][0]['sizeKB'])/1e+9
           imgurl = req.json()['images'][0]['url']
           namepath = os.path.splitext(path)[0]
           imgpath = f"{namepath}.preview.png"
           if not os.path.exists(f"{download_dir}/{path}"):
              download(download_dir, path, url, quiet=True)
              download(download_dir, imgpath, imgurl, quiet=True)
           else:
                pass
        else:
             parse = urlparse(url)
             path = os.path.basename(parse.path)
             convert = url.replace('resolve', 'raw')
             req = requests.get(convert, stream=True).text
             size = int(req.split("size ",1)[1])/1e+9
             if not os.path.exists(f"{download_dir}/{path}"):
                download(download_dir, path, url, quiet=True)
             else:
                  pass
    except:
           cp('Terjadi Error, Mohon cek ulang linknya', color='red')

os.chdir(repo_dir)

model_dir = os.path.join(repo_dir, "models")

for checkpoint in tqdm([cpoint, cpointurl], desc=cp("Mempersiapkan Model Checkpoint", color="flat_green")):
    downloading(url=cpoint, download_dir=f"{model_dir}/Stable-diffusion")
    if Custom_Download == "":
       pass
    else:
         downloading(url=cpointurl, download_dir=f"{model_dir}/Stable-diffusion")


def downloading(download_dir=None, url=None, quiet=True):
    try:
        parse = urlparse(url)
        path = os.path.basename(parse.path)
        convert = url.replace('resolve', 'raw')
        req = requests.get(convert, stream=True).text
        size = int(req.split("size ",1)[1])/1e+9
        if not os.path.exists(f"{download_dir}/{path}"):
          download(download_dir, path, url, quiet=True)
        else:
            pass
    except:
           cp('Terjadi Error, Mohon cek ulang linknya', color='red')

os.chdir(repo_dir)

cnet_model = f"{extensions_dir}/sd-{wui}-controlnet/models"
cnet_annonator = f"{extensions_dir}/sd-{wui}-controlnet/annotator"
openpose_dir = f"{cnet_annonator}/openpose"
mlsd_dir = f"{cnet_annonator}/mlsd"
midas_dir = f"{cnet_annonator}/midas"
hed_dir =  f"{cnet_annonator}/hed"
uniformer_dir =  f"{cnet_annonator}/uniformer"

cnet_canny = f"https://huggingface.co/{wui}/ControlNet-modules-safetensors/resolve/main/control_canny-fp16.safetensors"
cnet_depth = f"https://huggingface.co/{wui}/ControlNet-modules-safetensors/resolve/main/control_depth-fp16.safetensors"
cnet_hed = f"https://huggingface.co/{wui}/ControlNet-modules-safetensors/resolve/main/control_hed-fp16.safetensors"
cnet_mlsd = f"https://huggingface.co/{wui}/ControlNet-modules-safetensors/resolve/main/control_mlsd-fp16.safetensors"
cnet_normal = f"https://huggingface.co/{wui}/ControlNet-modules-safetensors/resolve/main/control_normal-fp16.safetensors"
cnet_openpose = f"https://huggingface.co/{wui}/ControlNet-modules-safetensors/resolve/main/control_openpose-fp16.safetensors"
cnet_scribble = f"https://huggingface.co/{wui}/ControlNet-modules-safetensors/resolve/main/control_scribble-fp16.safetensors"
cnet_seg = f"https://huggingface.co/{wui}/ControlNet-modules-safetensors/resolve/main/control_seg-fp16.safetensors"
hand_pose = "https://huggingface.co/ckpt/ControlNet/resolve/main/hand_pose_model.pth"
body_pose = "https://huggingface.co/ckpt/ControlNet/resolve/main/body_pose_model.pth"
midas = "https://huggingface.co/ckpt/ControlNet/resolve/main/dpt_hybrid-midas-501f0c75.pt"
mlsd1 = "https://huggingface.co/ckpt/ControlNet/resolve/main/mlsd_large_512_fp32.pth"
mlsd2 = "https://huggingface.co/ckpt/ControlNet/resolve/main/mlsd_tiny_512_fp32.pth"
network = "https://huggingface.co/ckpt/ControlNet/resolve/main/network-bsds500.pth"
uppernet = "https://huggingface.co/ckpt/ControlNet/resolve/main/upernet_global_small.pth"

list = [
        cnet_canny,
        cnet_depth,
        cnet_hed,
        cnet_mlsd,
        cnet_normal,
        cnet_openpose,
        cnet_scribble,
        cnet_seg,
        hand_pose,
        body_pose,
        mlsd1, mlsd2,
        midas, network,
        uppernet
        ]

for _ in tqdm(list, desc=cp("Mempersiapkan Controlnet Model", color="flat_green")):
    for model in cnet_canny, cnet_depth, cnet_hed, cnet_mlsd, cnet_normal, cnet_openpose, cnet_scribble, cnet_seg:
        downloading(cnet_model, model)
    for annonator1 in hand_pose, body_pose:
        downloading(openpose_dir, annonator1)
    for annonator2 in mlsd1, mlsd2:
        downloading(mlsd_dir, annonator2)
    downloading(midas_dir, midas)
    downloading(hed_dir, network)
    downloading(uniformer_dir, uppernet)

#install-vae-untuk-model-checkpoint-yang-akan-dipakai
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -d $vaepath -o vae-ft-mse-840000-ema-pruned.ckpt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/vorstcavry/vaecollection1/resolve/main/testclearvae.safetensors -d $vaepath -o testclearvae.safetensors

#install-lora
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/vorstcavry/loraasia1/resolve/main/japaneseDollLikeness_v15.safetensors -d /content/vorst-cavry/models/Lora/Lora-set -o japaneseDollLikeness_v15.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/vorstcavry/loraasia1/resolve/main/koreanDollLikeness_v20.safetensors -d /content/vorst-cavry/models/Lora/Lora-set -o koreanDollLikeness_v20.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/vorstcavry/loraasia1/resolve/main/taiwanDollLikeness_v15.safetensors -d /content/vorst-cavry/models/Lora/Lora-set -o taiwanDollLikeness_v15.safetensors

#intsall-lora-di-additional-networks
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/vorstcavry/loraasia1/resolve/main/japaneseDollLikeness_v15.safetensors -d $addnetworkpath -o japaneseDollLikeness_v15.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/vorstcavry/loraasia1/resolve/main/koreanDollLikeness_v20.safetensors -d $addnetworkpath -o koreanDollLikeness_v20.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/vorstcavry/loraasia1/resolve/main/taiwanDollLikeness_v15.safetensors -d $addnetworkpath -o taiwanDollLikeness_v15.safetensors

#install-Checkpoint
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/AnonPerson/ChilloutMix/resolve/main/ChilloutMix-ni-fp16.safetensors -d $basemodelpath -o ChilloutMix-ni-fp16.safetensors

#intsall-Preview-Checkpoint
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/vorstcavry/LoRA-set1/resolve/main/ChilloutMix-ni-fp16.preview.png -d $basemodelpath -o ChilloutMix-ni-fp16.preview.png

#Menjalankan web
os.chdir(repo_dir)
# %cd /content/vorst-cavry
# !git reset --hard

def prepare_environment():
    cprint(f"Mulai Mempersiapkan Link Stable Diffusion", color="green")

    os.environ["colab_url"]               = eval_js("google.colab.kernel.proxyPort(7860, {'cache': false})")
    os.environ["TF_CPP_MIN_LOG_LEVEL"]    = "3"
    os.environ["SAFETENSORS_FAST_GPU"]    = "1"
    os.environ['PYTORCH_CUDA_ALLOC_CONF'] = "garbage_collection_threshold:0.9,max_split_size_mb:512"
    os.environ["PYTHONWARNINGS"]          = "ignore"

prepare_environment()

# !sed -i -e '''/from modules import launch_utils/a\import os''' /content/vorst-cavry/launch.py
# !sed -i -e '''/        prepare_environment()/a\        os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /content/vorst-cavry/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /content/vorst-cavry/launch.py
# !sed -i -e 's/\["sd_model_checkpoint"\]/\["sd_model_checkpoint","sd_vae","CLIP_stop_at_last_layers"\]/g' /content/vorst-cavry/modules/shared.py

def parse_args(config):
    args = ""
    for k, v in config.items():
        if k.startswith("_"):
            args += f'"{v}" '
        elif isinstance(v, str):
            args += f'--{k}="{v}" '
        elif isinstance(v, bool) and v:
            args += f"--{k} "
        elif isinstance(v, float) and not isinstance(v, bool):
            args += f"--{k}={v} "
        elif isinstance(v, int) and not isinstance(v, bool):
            args += f"--{k}={v} "

    return args

config = {
    "enable-insecure-extension-access": True,
    "disable-safe-unpickle"           : True,
    "xformers"                        : True,
    "multiple "                       : True,
    "share"                           : True,
    "no-hashing"                      : True,
    "disable-console-progressbars"    : True,
    "opt-sub-quad-attention"          : True,
    "opt-channelslast"                : True,
    "theme"                           : "dark" if gunakan_tema_gelap else "light",
    "no-download-sd-model"            : True,
    "gradio-queue"                    : True,
    "listen"                          : True,
}

args = parse_args(config)
final_args = f"python launch.py {args}"

cp()
os.chdir(repo_dir)
os.environ["TCMALLOC_AGGRESSIVE_DECOMMIT"] = "t"
# !{final_args}
# Out:
#         <div style="
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             border: 2px solid #ccc;
#             background-color: #007bff;
#             width: 485px;
#             height: 30px;
#             color: white;
#             font-weight: bold;
#             text-align: center;
#         ">Terima kasih Telah Menggunakan Notebook google colab StableDiffusion milik Remaja Pekalongan.</div>
# <a href="https://www.youtube.com/@remajapekalongan" target="_blank"><img src="https://i.postimg.cc/Pf3XXMsP/Cuplikan-layar-2023-07-30-165548.png" width="489" height="172"></a>
# <div>
#         <style>
#             #subscribe {
#                 width: 119px;
#                 height: 40px;
#                 background-color: #007bff;
#                 color: white;
#                 border: 2px solid #ccc;
#                 cursor: pointer;
#                 transition: background-color 0.3s;
#             }
# ...

# %% [markdown]
# # <font color="#FF00FF">***TIPS UNTUK PEMULA***:</font>
# <img src="https://user-images.githubusercontent.com/73097560/115834477-dbab4500-a447-11eb-908a-139a6edaec5c.gif" width="800" height="18">

# %% [markdown]
# ##***1. Positive Prompt (hal2 yang diinginkan pada gambar)***
# Atau dalam kata lain adalah sebuah perintah atau permintaan untuk menyuruh sebuah AI di Stable Diffusion untuk menggambarkan gambar atau melakukan seuatu di stable diffuion sehingga menghasilkan karya seni yang sesuai atau hampir mendekati dengan perintah atau perintaan yang kamu berikan atau yang kamu inginkan
#
# ![Prompt.PNG](data:image/png;base64,...)
#
# ### **contoh sebuah prompt singkat**
#
# `1 girl`,
# `looking at viewer`,
# `smile,`,
# `standing`,
# `long hair`,
# `white suit`,
# `hair ribbon`,
#
# ### **Jika prompt yang di atas dijadikan sebuah kalimat akan menjadi seperti ini**
#
#
# artinya kamu menginginkan gambar dengan `satu orang gadis` `berrambut panjang` yang `memakai pita rambut`, `sedang melihat kearahmu`,` dengan senyuman.`
#
# ### Prompt hanyalah sebuah detail kecil untuk menggambarkan sesuatu pada gambarmu

# %% [markdown]
# ##***2. Negative Prompt (hal2 yang tidak diinginkan pada gambar)***
#
# Atau dalam kata lain adalah sebuah perintah atau larangan untuk menyuruh sebuah AI di Stable Diffusion tidak menggambarkan gambar sesuaitu atau melakukan seuatu di stable diffuion yang tidak kalian inginkan dan sehingga menghasilkan karya seni yang sesuai atau hampir mendekati dengan perintah atau larangan yang kamu berikan atau yang kamu inginkan
#
# ![Negative Prompt.PNG](data:image/png;base64,...)
#
# seperti contoh :
#
# `bad anatomy`,
# `bad hands`,
# `bar censor`,
# `censored`,
# `disconnected limbs`,
# `extra digits`,
# `fewer digits`,
# `floating limbs`,
# `low quality`,
# `low res`,
# `missing fingers`,
# `missing limbs`,
# `mutated fingers`,
# `mutated hands`,
# `normal quality`,
# `out of frame`,
# `poorly drawn`,
# `porn`,
# `trademark`,
# `ugly`,
# `watermark`,
# `worst quality`,
#
# ### **Jika prompt Negatif di atas di artikan dalam bahasa kita**
#
#
# artinya kamu tidak menginginkan gambar yang memiliki `anatomi yang buruk`, `tangan yang buruk`, `sensor bar`, `disensor`, `anggota badan yang terputus`, `angka tambahan`, `lebih sedikit angka`, `anggota badan mengambang`, `kualitas rendah`, `resolusi rendah`, `jari-jari yang hilang`, `anggota badan yang hilang`, `jari yang bermutasi`, `tangan yang bermutasi`, `kualitas normal`, `keluar dari frame`, `digambar dengan buruk`, `pornografi`, `tanda air`, `kualitas buruk`,
#
# ### Negatif Prompt hanyalah sebuah larangan yang diberikan oleh dirimu untuk AI agar AI tidak menggambarkan sesuatu yang tidak di inginkan pada yang akan di buat

# %% [markdown]
# ##***3.Cara Menggunakan Additional Networks*** <small><small><small><font color="#00CED1">**Sulit digunkan untuk Pengguna HandPhone**:</font> </small></small>
#
# * Langkah Pertama Letakkan model LoRA yang memiliki Format seperti(*.pt, *.ckpt atau *.safetensors) di dalam folder sd-webui-additional-networks/models/LoRA.
#
# * Buka panel "Additional Networks" dari bagian kiri bawah Web UI.
#
# * Tekan "Refresh models" untuk memperbarui daftar model.
#
# * Pilih "LoRA" untuk "Modul jaringan 1".
#
# * Pilih nama file model LoRA di "Model 1".
#
# * Tetapkan bobot model (bobot negatif mungkin dapat bekerja tetapi tidak diharapkan.)
#
# * Ulangi untuk modul/model/bobot 2 sampai 5 jika anda memiliki model lain. Model diterapkan dalam urutan 1 sampai 5.
#
# * Kalian dapat menghasilkan gambar dengan model dengan jaringan tambahan ini.

# %% [markdown]
# ##***4.Cara Menggunakan LoRA***
#
# Cara untuk mengetahui model LoRA apa saja yang dimiliki :
#
# ![17](https://drive.google.com/uc?export=view&id=1mZKUl2hZ0n0MpKNK6cge9ovQuGYfKQc0)
#
# Tekan Tombol Kotak Merah yang ada lingkaran putih ini
#
# setelah tombol kotak kecil merah di klik akan muncul menu berikut :
#
# ![18](https://drive.google.com/uc?export=view&id=1hpAd80k71tqS8SruYMGoSJi-nYdeGDVs)
#
# Tekan model LoRA untuk Menggunkannya, Kemudian model LoRA tecantum ke prompt. `Bukan yang di Negatif Prompt`
#
# Format nama Lora yang akan keluar <lora - nama file - skala> :
#
# `1girl`, `smile`, `<lora:doll_japan:1>`
#
# angka 1 di belakang lora di tujukan untuk besaran lora yang akan digunakan,
# angka 1 artinya `100%`
#
# Contoh
# `0.1` = `10%`
# `0.2` = `20%`
# `0.3` = `30%`
# Dan seterusnya
#
# jika kalian menginginkan penggunaan Dua LoRA atau lebih, kalian dapat mengurangi Skala/Rasio Loranya.
#
# **Contoh :**
#
# `1girl, smile, <lora:doll_japan:0.7> <lora:doll_korea:0.3>`
#
# Lora doll_japan `0.7` dan Lora doll_korea` 0.3`
#
# artinya adalah Lora doll_japan akan keluar sebesar `70%`dan lora doll_korea akan keluar sebesar `30%`

# %% [markdown]
# ##***5. Cara Mengganti Checkpoint yang dimiliki***
#
# tekan Model Checkpoint untuk melihat model apa saja yang dimiliki :
#
# ![Ubah Model 1.jpg](data:image/jpeg;base64,...)
#
# Setelah itu kalian bisa memilih Model Checkpoint yang akan digunakan :
#
# ![Ubah Model 2.jpg](data:image/jpeg;base64,...)
